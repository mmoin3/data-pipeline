# %%
import os, sys
from pathlib import Path
import pandas as pd
sys.path.append(str(Path("..").resolve()))
from config import *
from src.services.statestreet_mft_client import StateStreetMFTClient

# %%
with StateStreetMFTClient() as client:
    files = client.list_files("/ETFGlobalHarvest/fromSSC")
    downloaded_files = []
    
    for file_info in files:
        if not file_info.get("directory"):
            filename = file_info.get("filename")
            remote_path = f"/ETFGlobalHarvest/fromSSC/{filename}"
            file_path = client.download(remote_path, skip_existing=True)
            downloaded_files.append(file_path)
# Out:
# INFO:src.services.statestreet_mft_client:Authenticated with MFT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260320.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260323.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260324.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260324.REVISED.01.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260325.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260326.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260327.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260330.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260331.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260401.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_BSKT.20260402.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260320.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260323.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260324.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260325.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260326.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260327.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260330.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260331.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260401.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_CIL_ALL.20260402.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260320.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260323.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260324.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260324.REVISED.01.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260325.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260326.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260327.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260330.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260331.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260401.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INAVBSKT_ALL.20260402.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260324.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260327.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260330.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260331.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260401.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_INKIND.20260402.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260320.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260323.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260324.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260325.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260326.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260327.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260330.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260331.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260401.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_NAV_ALL.20260402.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260327.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260330.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260331.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260401.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260402.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_Preburst_INKIND_ALL.20260406.TXT
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_UCF.20260327.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_UCF.20260330.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_UCF.20260331.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_UCF.20260401.CSV
# INFO:src.services.statestreet_mft_client:Skipped (exists): Harvest_UCF.20260402.CSV
