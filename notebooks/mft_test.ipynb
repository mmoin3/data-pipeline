# %%
import os, sys
from pathlib import Path
import pandas as pd
sys.path.append(str(Path("..").resolve()))
from config import *
from src.services.statestreet_mft_client import StateStreetMFTClient

# %%
with StateStreetMFTClient() as client:
    # Download single file
    file_name = f"Harvest_Preburst_INKIND_ALL.{pd.Timestamp.now().strftime('%Y%m%d')}.TXT"
    # file_name = f"Harvest_Preburst_INKIND_ALL.20260323.TXT"
    client.download(
        f"/ETFGlobalHarvest/fromSSC/{file_name}",
        ROOT_DIR/"notebooks"/file_name,
        )
# Out:
# INFO:src.services.statestreet_mft_client:Authenticated with MFT
# INFO:src.services.statestreet_mft_client:Downloading: C:\Users\mmoin\PYTHON PROJECTS\data-pipeline\notebooks\Harvest_Preburst_INKIND_ALL.20260324.TXT
# INFO:src.services.statestreet_mft_client:Downloaded: C:\Users\mmoin\PYTHON PROJECTS\data-pipeline\notebooks\Harvest_Preburst_INKIND_ALL.20260324.TXT
