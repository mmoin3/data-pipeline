# %%
import os, sys
import importlib
sys.path.append(os.path.abspath('..'))
import pandas as pd
from src.services.mail_client import send_email
# from src.extract import INAVBskt
import src.parsers.inav_bskt as inav_bskt_module
inav_bskt_module = importlib.reload(inav_bskt_module)
INAVBskt = inav_bskt_module.INAVBskt
import src.dataframe_cleaner as dataframe_cleaner_module
dataframe_cleaner_module = importlib.reload(dataframe_cleaner_module)
clean = dataframe_cleaner_module.clean
from config.settings import *
from src.extract import load_into_bronze

# %%
bskt_file = os.path.join(DATA_DIR, 'Harvest_INAVBSKT_ALL.20260218.csv')

# %%
fil12 = INAVBskt(bskt_file)
df12 = fil12.extract()
print(df12[0])
# Out:
# {'fund_metadata':   TRADE_DATE SS_LONG_CODE                                          FULL_NAME  \
# 0   20260219      HR21APR  Harvest Tech Achievers Growth & Income ETF Cla...
#
#   TICKER_1 TICKER_2 BASE_CURRENCY INSTRUCTION_ASSET CREATION_UNIT_SIZE  \
# 0     'HTA     'HTA           CAD             DUMMY            1000000
#
#   DOMICILE ESTIMATED_DIVIDENDS  ... ESTIMATED_CASH_IN_LIEU  \
# 0                      2890.17  ...             -274038.28
#
#   REDEEM_VARIABLE_FEE ETF_SHARES_OUTSTANDING ACTUAL_INTEREST  \
# 0                   0               37376707               0
#
#   ESTIMATED_INTEREST EXPENSE_RATIO TOTAL_NET_ASSETS ACTUAL_TOTAL_CASH  \
# 0                  0             1     681938489.46        -227920.17
#
#   ESTIMATED_TOTAL_CASH THRESHOLD
# 0           -276906.89
#
# [1 rows x 38 columns], 'fund_holdings':          CUSIP          TICKER     SEDOL          ISIN  \
# 0   '007903107            'AMD  '2007849  US0079031078
# ...

# %%
print(df12[0]['fund_metadata'])
df12[0]['fund_metadata'].to_csv('testing.csv',index=False)
# Out:
#   TRADE_DATE SS_LONG_CODE                                          FULL_NAME  \
# 0   20260219      HR21APR  Harvest Tech Achievers Growth & Income ETF Cla...
#
#   TICKER_1 TICKER_2 BASE_CURRENCY INSTRUCTION_ASSET CREATION_UNIT_SIZE  \
# 0     'HTA     'HTA           CAD             DUMMY            1000000
#
#   DOMICILE ESTIMATED_DIVIDENDS  ... ESTIMATED_CASH_IN_LIEU  \
# 0                      2890.17  ...             -274038.28
#
#   REDEEM_VARIABLE_FEE ETF_SHARES_OUTSTANDING ACTUAL_INTEREST  \
# 0                   0               37376707               0
#
#   ESTIMATED_INTEREST EXPENSE_RATIO TOTAL_NET_ASSETS ACTUAL_TOTAL_CASH  \
# 0                  0             1     681938489.46        -227920.17
#
#   ESTIMATED_TOTAL_CASH THRESHOLD
# 0           -276906.89
#
# [1 rows x 38 columns]

# %%
if not df12:
    raise ValueError("Parser returned no fund blocks. Re-run the import/extract cells and verify bskt_file path.")

df12_cleaned = clean(df12[0]['fund_metadata'], schema=FUND_METADATA_TYPE_MAP)
df12_cleaned.to_csv("testing_cleaned.csv", index=False)

# %%
load_into_bronze(df12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 load_into_bronze()
#
# TypeError: load_into_bronze() missing 1 required positional argument: 'df12'
